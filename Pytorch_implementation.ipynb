# %% [markdown]
# <a href="https://colab.research.google.com/github/cosineDaDa0623/2023_Summer_Intern/blob/master/Pytorch_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install RDkit
# RDkit is used to convert smiles to ECFP which is used to train the model

# %%
# !pip install rdkit
# Out:
# Requirement already satisfied: rdkit in /usr/local/lib/python3.10/dist-packages (2023.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)

# %% [markdown]
# # Package import
# Import the necessary packages

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs
import pandas as pd #Pandas have Dataframe, so the manipulation of data is efficient and convenient
import numpy as np #Linear math packages, which are important for the data
from google.colab import drive #Just used to get file from the google drive
drive.mount('/content/drive')
df = pd.read_excel('/content/drive/MyDrive/5HT2A models data.xlsx')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/5HT2A models data.xlsx')

# %%
#Import Pytorch which is a commonly-used deeplearning package
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch import nn

# %% [markdown]
# # Dataset building

# %%
#get the ecfp from the smiles
def smiles_to_ecfp4(smiles_string):
  mol = Chem.MolFromSmiles(smiles_string)
  ecfp4 = AllChem.GetMorganFingerprintAsBitVect(mol, radius=4, nBits=2048)
  return ecfp4
#the labels are strings, so we must convert them into numbers
def get_response(ligand_class):
  convert_dic = {
      'dude_active' : 0,
      'dude_inactive' : 1,
      'HTR2A_Antagonist_1.0' : 2,
      'HTR2A_Antagonist_0.0' : 3,
      'HTR2A_Agonist_1.0' : 4,
      'HTR2A_Agonist_0.0' : 5,
      'HTR2A_Inverse Agonist_1.0' : 6
}
  return convert_dic[ligand_class]
#Now construct the dataset
#So we can use the data when training the model
class Compound(Dataset):
  #initialization of the dataset. We can automatically construct the dataset from the input file
  def __init__(self, inputfile):
    df = pd.read_excel(inputfile)
    df['ECFP4'] = df['smiles'].apply(smiles_to_ecfp4)
    df['response'] = df['ligand_class'].apply(get_response)
    self.dataframe = df
    self.response = df['response']
    self.fingerprint = df['ECFP4']
  #get the length of the dataset
  def __len__(self):
    return len(self.dataframe)
  #Dataset iteration function
  def __getitem__(self, idx):
    feature = np.array(self.fingerprint[idx].ToList()).astype(float)
    label = self.response[idx]
    return feature, label

# %% [markdown]
# # Split the Dataset into train, validate, and test dataset

# %%
import numpy as np
from sklearn.model_selection import train_test_split # this pacakge is used to split the dataset into train, validate and test datasets
from torch.utils.data import Subset #this package is used to create subsets

# %%
def split_the_dataset(in_dataset, train_frac = 0.7, valid_frac = 0.15, test_frac = 0.15, seed = 42):
  #in_dataset: the dataset you want to split
  #train_frac, valid_frac, test_frac: the fraction of subsets
  assert test_frac + valid_frac + train_frac == 1.0 # check if the sum of three fracs is 1
  labels = [in_dataset[i][1] for i in range(len(in_dataset))] # get the label of the dataset, warning: this function only supports 1 label
  # split the datasets while keep the label fraction the same
  train_idx, temp_test_idx = train_test_split(
    np.arange(len(labels)),
    test_size = 1 - test_frac,
    stratify=labels,
    random_state=seed
  )
  valid_idx, test_idx = train_test_split(
    temp_test_idx,
    test_size = test_frac / (valid_frac + test_frac),
    stratify = [labels[i] for i in temp_test_idx],
    random_state = seed
  )
  #get the datasets by using subset package
  train_dataset = Subset(in_dataset, train_idx)
  valid_dataset = Subset(in_dataset, valid_idx)
  test_dataset = Subset(in_dataset, test_idx)
  #return the splitted dataset
  return train_dataset, valid_dataset, test_dataset

# %%
compound_set = Compound('/content/drive/MyDrive/5HT2A models data.xlsx')
tr, va, tt = split_the_dataset(compound_set)
train_loader = DataLoader(tr, batch_size=32, shuffle=True)
valid_loader = DataLoader(va, batch_size=32, shuffle=False)
test_loader = DataLoader(tt, batch_size=32, shuffle=False)

# %%
for x, y in train_loader:
  print(x.size())
  print(y.size())
  break
# Out:
# torch.Size([32, 2048])
# torch.Size([32])

# %% [markdown]
# # Model building

# %% [markdown]
# ## Simple NN

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class NN1(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_layers = nn.Sequential(
            nn.Linear(2048, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, 7)
        )

    def forward(self, x):
        return self.linear_layers(x)

# %%
loss_fn = nn.CrossEntropyLoss()
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    # Set the model to training mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # print(X.type())
        # print(y.type())
        # print(X)
        # break
        # Compute prediction and loss
        X = X.float()
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
from sklearn.metrics import precision_score, recall_score, f1_score, matthews_corrcoef

def test_loop(dataloader, model, loss_fn):
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    # Keep track of true and predicted labels for additional metrics
    all_true_labels = []
    all_predicted_labels = []

    with torch.no_grad():
        for X, y in dataloader:
            X = X.float()
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

            # Add true labels and predicted labels to lists
            all_true_labels.extend(y.tolist())
            all_predicted_labels.extend(pred.argmax(1).tolist())

    test_loss /= num_batches
    correct /= size

    # Compute additional metrics
    precision = precision_score(all_true_labels, all_predicted_labels, average='macro')
    recall = recall_score(all_true_labels, all_predicted_labels, average='macro')
    f1 = f1_score(all_true_labels, all_predicted_labels, average='macro')
    mcc = matthews_corrcoef(all_true_labels, all_predicted_labels)

    print(f"Test Error: ")
    print(f" Accuracy: {(100*correct):>0.1f}%")
    print(f" Avg loss: {test_loss:>8f}")
    print(f" Precision: {precision:>0.4f}")
    print(f" Recall: {recall:>0.4f}")
    print(f" F1 Score: {f1:>0.4f}")
    print(f" Matthew's Correlation Coefficient: {mcc:>0.4f}")

# %%
nn1 = NN1()
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(nn1.parameters(), lr=0.01)

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_loader, nn1, loss_fn, optimizer)
    test_loop(test_loader, nn1, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.135488  [   32/ 3422]
# loss: 1.010485  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 75.7%
#  Avg loss: 1.003070
#  Precision: 0.3289
#  Recall: 0.3413
#  F1 Score: 0.3321
#  Matthew's Correlation Coefficient: 0.6354
# Epoch 2
# -------------------------------
# loss: 0.869270  [   32/ 3422]
# loss: 0.476328  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 80.2%
#  Avg loss: 0.706125
#  Precision: 0.4721
#  Recall: 0.3702
#  F1 Score: 0.3592
#  Matthew's Correlation Coefficient: 0.7032
# Epoch 3
# -------------------------------
# loss: 0.466625  [   32/ 3422]
# loss: 0.553010  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 83.1%
#  Avg loss: 0.579204
#  Precision: 0.4686
#  Recall: 0.3961
#  F1 Score: 0.3930
#  Matthew's Correlation Coefficient: 0.7490
# Epoch 4
# -------------------------------
# loss: 0.389613  [   32/ 3422]
# loss: 0.483849  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 84.8%
#  Avg loss: 0.515018
#  Precision: 0.4569
#  Recall: 0.4188
#  F1 Score: 0.4191
#  Matthew's Correlation Coefficient: 0.7766
# Epoch 5
# -------------------------------
# loss: 0.524752  [   32/ 3422]
# loss: 0.382219  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 85.9%
#  Avg loss: 0.471679
#  Precision: 0.4502
#  Recall: 0.4472
#  F1 Score: 0.4459
#  Matthew's Correlation Coefficient: 0.7925
# Epoch 6
# -------------------------------
# loss: 0.562221  [   32/ 3422]
# loss: 0.266042  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 86.8%
#  Avg loss: 0.443795
#  Precision: 0.4507
#  Recall: 0.4653
#  F1 Score: 0.4574
#  Matthew's Correlation Coefficient: 0.8054
# Epoch 7
# -------------------------------
# loss: 0.204200  [   32/ 3422]
# loss: 0.199998  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 87.5%
#  Avg loss: 0.424163
#  Precision: 0.4568
#  Recall: 0.4797
#  F1 Score: 0.4673
#  Matthew's Correlation Coefficient: 0.8155
# Epoch 8
# -------------------------------
# loss: 0.443090  [   32/ 3422]
# loss: 0.122772  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 88.2%
#  Avg loss: 0.398992
#  Precision: 0.4625
#  Recall: 0.4894
#  F1 Score: 0.4746
#  Matthew's Correlation Coefficient: 0.8257
# Epoch 9
# -------------------------------
# loss: 0.169165  [   32/ 3422]
# loss: 0.161920  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 88.3%
#  Avg loss: 0.388651
#  Precision: 0.4636
#  Recall: 0.4942
#  F1 Score: 0.4770
#  Matthew's Correlation Coefficient: 0.8275
# Epoch 10
# -------------------------------
# loss: 0.194091  [   32/ 3422]
# loss: 0.224921  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 87.9%
#  Avg loss: 0.400230
#  Precision: 0.4573
#  Recall: 0.5009
#  F1 Score: 0.4735
#  Matthew's Correlation Coefficient: 0.8232
# Epoch 11
# -------------------------------
# loss: 0.167197  [   32/ 3422]
# loss: 0.144460  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 88.0%
#  Avg loss: 0.394951
#  Precision: 0.4594
#  Recall: 0.4980
#  F1 Score: 0.4752
#  Matthew's Correlation Coefficient: 0.8254
# Epoch 12
# -------------------------------
# loss: 0.059135  [   32/ 3422]
# loss: 0.476877  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 88.3%
#  Avg loss: 0.386946
#  Precision: 0.5564
#  Recall: 0.5106
#  F1 Score: 0.4963
#  Matthew's Correlation Coefficient: 0.8290
# Epoch 13
# -------------------------------
# loss: 0.052876  [   32/ 3422]
# loss: 0.390995  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 89.0%
#  Avg loss: 0.366357
#  Precision: 0.5720
#  Recall: 0.5276
#  F1 Score: 0.5188
#  Matthew's Correlation Coefficient: 0.8390
# Epoch 14
# -------------------------------
# loss: 0.319659  [   32/ 3422]
# loss: 0.251549  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 88.7%
#  Avg loss: 0.375609
#  Precision: 0.5634
#  Recall: 0.5238
#  F1 Score: 0.5108
#  Matthew's Correlation Coefficient: 0.8346
# Epoch 15
# -------------------------------
# loss: 0.294939  [   32/ 3422]
# loss: 0.299140  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 88.7%
#  Avg loss: 0.376902
#  Precision: 0.5648
#  Recall: 0.5369
#  F1 Score: 0.5284
#  Matthew's Correlation Coefficient: 0.8348
# Epoch 16
# -------------------------------
# loss: 0.039623  [   32/ 3422]
# loss: 0.122495  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 89.0%
#  Avg loss: 0.375856
#  Precision: 0.5772
#  Recall: 0.5616
#  F1 Score: 0.5562
#  Matthew's Correlation Coefficient: 0.8387
# Epoch 17
# -------------------------------
# loss: 0.292024  [   32/ 3422]
# loss: 0.025998  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 89.0%
#  Avg loss: 0.374966
#  Precision: 0.5746
#  Recall: 0.5471
#  F1 Score: 0.5415
#  Matthew's Correlation Coefficient: 0.8389
# Epoch 18
# -------------------------------
# loss: 0.114413  [   32/ 3422]
# loss: 0.062326  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 88.8%
#  Avg loss: 0.384682
#  Precision: 0.5730
#  Recall: 0.5607
#  F1 Score: 0.5553
#  Matthew's Correlation Coefficient: 0.8373
# Epoch 19
# -------------------------------
# loss: 0.157080  [   32/ 3422]
# loss: 0.039685  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 89.0%
#  Avg loss: 0.381065
#  Precision: 0.5685
#  Recall: 0.5643
#  F1 Score: 0.5569
#  Matthew's Correlation Coefficient: 0.8394
# Epoch 20
# -------------------------------
# loss: 0.108468  [   32/ 3422]
# loss: 0.089307  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 89.4%
#  Avg loss: 0.368329
#  Precision: 0.5729
#  Recall: 0.5746
#  F1 Score: 0.5663
#  Matthew's Correlation Coefficient: 0.8442
# Epoch 21
# -------------------------------
# loss: 0.056252  [   32/ 3422]
# loss: 0.114595  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 89.2%
#  Avg loss: 0.378244
#  Precision: 0.5736
#  Recall: 0.5868
#  F1 Score: 0.5758
#  Matthew's Correlation Coefficient: 0.8429
# Epoch 22
# -------------------------------
# loss: 0.038290  [   32/ 3422]
# loss: 0.026192  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 89.2%
#  Avg loss: 0.379940
#  Precision: 0.5700
#  Recall: 0.5894
#  F1 Score: 0.5744
#  Matthew's Correlation Coefficient: 0.8429
# Epoch 23
# -------------------------------
# loss: 0.080872  [   32/ 3422]
# loss: 0.040290  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 89.3%
#  Avg loss: 0.382915
#  Precision: 0.5700
#  Recall: 0.5818
#  F1 Score: 0.5701
#  Matthew's Correlation Coefficient: 0.8434
# Epoch 24
# -------------------------------
# loss: 0.104930  [   32/ 3422]
# loss: 0.089443  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 88.7%
#  Avg loss: 0.399413
#  Precision: 0.5553
#  Recall: 0.5988
#  F1 Score: 0.5719
#  Matthew's Correlation Coefficient: 0.8356
# Epoch 25
# -------------------------------
# loss: 0.042983  [   32/ 3422]
# loss: 0.074815  [ 3232/ 3422]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Error:
#  Accuracy: 89.3%
#  Avg loss: 0.389133
#  Precision: 0.5697
#  Recall: 0.5998
#  F1 Score: 0.5802
#  Matthew's Correlation Coefficient: 0.8442
# Epoch 26
# -------------------------------
# loss: 0.173765  [   32/ 3422]
# loss: 0.074131  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.3%
#  Avg loss: 0.393209
#  Precision: 0.7076
#  Recall: 0.6057
#  F1 Score: 0.5905
#  Matthew's Correlation Coefficient: 0.8428
# Epoch 27
# -------------------------------
# loss: 0.042902  [   32/ 3422]
# loss: 0.050421  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.3%
#  Avg loss: 0.393785
#  Precision: 0.7037
#  Recall: 0.6076
#  F1 Score: 0.5896
#  Matthew's Correlation Coefficient: 0.8432
# Epoch 28
# -------------------------------
# loss: 0.074874  [   32/ 3422]
# loss: 0.014255  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.7%
#  Avg loss: 0.385769
#  Precision: 0.8196
#  Recall: 0.6168
#  F1 Score: 0.6128
#  Matthew's Correlation Coefficient: 0.8488
# Epoch 29
# -------------------------------
# loss: 0.066102  [   32/ 3422]
# loss: 0.198672  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.7%
#  Avg loss: 0.388721
#  Precision: 0.7990
#  Recall: 0.6194
#  F1 Score: 0.6179
#  Matthew's Correlation Coefficient: 0.8485
# Epoch 30
# -------------------------------
# loss: 0.084621  [   32/ 3422]
# loss: 0.097151  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.5%
#  Avg loss: 0.393434
#  Precision: 0.8021
#  Recall: 0.6151
#  F1 Score: 0.6050
#  Matthew's Correlation Coefficient: 0.8458
# Epoch 31
# -------------------------------
# loss: 0.016011  [   32/ 3422]
# loss: 0.019737  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.3%
#  Avg loss: 0.402881
#  Precision: 0.7649
#  Recall: 0.6220
#  F1 Score: 0.6142
#  Matthew's Correlation Coefficient: 0.8443
# Epoch 32
# -------------------------------
# loss: 0.031998  [   32/ 3422]
# loss: 0.331037  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.5%
#  Avg loss: 0.402433
#  Precision: 0.7978
#  Recall: 0.6222
#  F1 Score: 0.6176
#  Matthew's Correlation Coefficient: 0.8461
# Epoch 33
# -------------------------------
# loss: 0.170082  [   32/ 3422]
# loss: 0.063737  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.4%
#  Avg loss: 0.396965
#  Precision: 0.7991
#  Recall: 0.6325
#  F1 Score: 0.6346
#  Matthew's Correlation Coefficient: 0.8449
# Epoch 34
# -------------------------------
# loss: 0.054021  [   32/ 3422]
# loss: 0.019387  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.7%
#  Avg loss: 0.405374
#  Precision: 0.8072
#  Recall: 0.6298
#  F1 Score: 0.6343
#  Matthew's Correlation Coefficient: 0.8492
# Epoch 35
# -------------------------------
# loss: 0.075849  [   32/ 3422]
# loss: 0.010370  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.4%
#  Avg loss: 0.409508
#  Precision: 0.7361
#  Recall: 0.6332
#  F1 Score: 0.6305
#  Matthew's Correlation Coefficient: 0.8450
# Epoch 36
# -------------------------------
# loss: 0.085551  [   32/ 3422]
# loss: 0.075084  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.7%
#  Avg loss: 0.406631
#  Precision: 0.7602
#  Recall: 0.6366
#  F1 Score: 0.6388
#  Matthew's Correlation Coefficient: 0.8482
# Epoch 37
# -------------------------------
# loss: 0.013562  [   32/ 3422]
# loss: 0.156508  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.8%
#  Avg loss: 0.403972
#  Precision: 0.7357
#  Recall: 0.6547
#  F1 Score: 0.6581
#  Matthew's Correlation Coefficient: 0.8508
# Epoch 38
# -------------------------------
# loss: 0.013012  [   32/ 3422]
# loss: 0.098284  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.6%
#  Avg loss: 0.412883
#  Precision: 0.7498
#  Recall: 0.6403
#  F1 Score: 0.6443
#  Matthew's Correlation Coefficient: 0.8478
# Epoch 39
# -------------------------------
# loss: 0.018184  [   32/ 3422]
# loss: 0.017144  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.7%
#  Avg loss: 0.412948
#  Precision: 0.7484
#  Recall: 0.6472
#  F1 Score: 0.6486
#  Matthew's Correlation Coefficient: 0.8481
# Epoch 40
# -------------------------------
# loss: 0.010439  [   32/ 3422]
# loss: 0.008278  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.4%
#  Avg loss: 0.424786
#  Precision: 0.7459
#  Recall: 0.6557
#  F1 Score: 0.6539
#  Matthew's Correlation Coefficient: 0.8452
# Epoch 41
# -------------------------------
# loss: 0.033988  [   32/ 3422]
# loss: 0.022661  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.6%
#  Avg loss: 0.423190
#  Precision: 0.7254
#  Recall: 0.6505
#  F1 Score: 0.6528
#  Matthew's Correlation Coefficient: 0.8474
# Epoch 42
# -------------------------------
# loss: 0.076213  [   32/ 3422]
# loss: 0.055655  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.9%
#  Avg loss: 0.419272
#  Precision: 0.7354
#  Recall: 0.6646
#  F1 Score: 0.6711
#  Matthew's Correlation Coefficient: 0.8512
# Epoch 43
# -------------------------------
# loss: 0.033110  [   32/ 3422]
# loss: 0.005688  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.6%
#  Avg loss: 0.419114
#  Precision: 0.7028
#  Recall: 0.6678
#  F1 Score: 0.6669
#  Matthew's Correlation Coefficient: 0.8476
# Epoch 44
# -------------------------------
# loss: 0.016292  [   32/ 3422]
# loss: 0.023999  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.5%
#  Avg loss: 0.425327
#  Precision: 0.7121
#  Recall: 0.6655
#  F1 Score: 0.6664
#  Matthew's Correlation Coefficient: 0.8459
# Epoch 45
# -------------------------------
# loss: 0.056532  [   32/ 3422]
# loss: 0.005628  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.6%
#  Avg loss: 0.431607
#  Precision: 0.7103
#  Recall: 0.6620
#  F1 Score: 0.6630
#  Matthew's Correlation Coefficient: 0.8474
# Epoch 46
# -------------------------------
# loss: 0.026847  [   32/ 3422]
# loss: 0.015918  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.9%
#  Avg loss: 0.417683
#  Precision: 0.6987
#  Recall: 0.6771
#  F1 Score: 0.6760
#  Matthew's Correlation Coefficient: 0.8524
# Epoch 47
# -------------------------------
# loss: 0.052449  [   32/ 3422]
# loss: 0.069302  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.6%
#  Avg loss: 0.440708
#  Precision: 0.7188
#  Recall: 0.6755
#  F1 Score: 0.6805
#  Matthew's Correlation Coefficient: 0.8470
# Epoch 48
# -------------------------------
# loss: 0.005743  [   32/ 3422]
# loss: 0.010130  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.414136
#  Precision: 0.6987
#  Recall: 0.6848
#  F1 Score: 0.6833
#  Matthew's Correlation Coefficient: 0.8534
# Epoch 49
# -------------------------------
# loss: 0.025345  [   32/ 3422]
# loss: 0.070067  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.1%
#  Avg loss: 0.415225
#  Precision: 0.6983
#  Recall: 0.6899
#  F1 Score: 0.6872
#  Matthew's Correlation Coefficient: 0.8544
# Epoch 50
# -------------------------------
# loss: 0.004851  [   32/ 3422]
# loss: 0.007172  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.420606
#  Precision: 0.7125
#  Recall: 0.7071
#  F1 Score: 0.7047
#  Matthew's Correlation Coefficient: 0.8534
# Epoch 51
# -------------------------------
# loss: 0.042436  [   32/ 3422]
# loss: 0.063105  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.9%
#  Avg loss: 0.422468
#  Precision: 0.7282
#  Recall: 0.6968
#  F1 Score: 0.7022
#  Matthew's Correlation Coefficient: 0.8523
# Epoch 52
# -------------------------------
# loss: 0.017669  [   32/ 3422]
# loss: 0.004524  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.3%
#  Avg loss: 0.444958
#  Precision: 0.7067
#  Recall: 0.6655
#  F1 Score: 0.6664
#  Matthew's Correlation Coefficient: 0.8443
# Epoch 53
# -------------------------------
# loss: 0.041514  [   32/ 3422]
# loss: 0.092276  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.433362
#  Precision: 0.7122
#  Recall: 0.6888
#  F1 Score: 0.6887
#  Matthew's Correlation Coefficient: 0.8531
# Epoch 54
# -------------------------------
# loss: 0.027129  [   32/ 3422]
# loss: 0.118542  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.8%
#  Avg loss: 0.435487
#  Precision: 0.7069
#  Recall: 0.6966
#  F1 Score: 0.6948
#  Matthew's Correlation Coefficient: 0.8499
# Epoch 55
# -------------------------------
# loss: 0.010489  [   32/ 3422]
# loss: 0.002604  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.7%
#  Avg loss: 0.437563
#  Precision: 0.7026
#  Recall: 0.7028
#  F1 Score: 0.6996
#  Matthew's Correlation Coefficient: 0.8498
# Epoch 56
# -------------------------------
# loss: 0.035489  [   32/ 3422]
# loss: 0.047753  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.4%
#  Avg loss: 0.435139
#  Precision: 0.7144
#  Recall: 0.7198
#  F1 Score: 0.7120
#  Matthew's Correlation Coefficient: 0.8593
# Epoch 57
# -------------------------------
# loss: 0.001856  [   32/ 3422]
# loss: 0.003787  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.436303
#  Precision: 0.6994
#  Recall: 0.7224
#  F1 Score: 0.7060
#  Matthew's Correlation Coefficient: 0.8527
# Epoch 58
# -------------------------------
# loss: 0.147179  [   32/ 3422]
# loss: 0.055316  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.5%
#  Avg loss: 0.445154
#  Precision: 0.6926
#  Recall: 0.7199
#  F1 Score: 0.7027
#  Matthew's Correlation Coefficient: 0.8463
# Epoch 59
# -------------------------------
# loss: 0.005616  [   32/ 3422]
# loss: 0.059366  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.9%
#  Avg loss: 0.441100
#  Precision: 0.6922
#  Recall: 0.7012
#  F1 Score: 0.6930
#  Matthew's Correlation Coefficient: 0.8511
# Epoch 60
# -------------------------------
# loss: 0.106751  [   32/ 3422]
# loss: 0.024941  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.9%
#  Avg loss: 0.440418
#  Precision: 0.7104
#  Recall: 0.7014
#  F1 Score: 0.7026
#  Matthew's Correlation Coefficient: 0.8515
# Epoch 61
# -------------------------------
# loss: 0.003796  [   32/ 3422]
# loss: 0.002928  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.3%
#  Avg loss: 0.453475
#  Precision: 0.6907
#  Recall: 0.7110
#  F1 Score: 0.6974
#  Matthew's Correlation Coefficient: 0.8441
# Epoch 62
# -------------------------------
# loss: 0.011565  [   32/ 3422]
# loss: 0.002568  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.3%
#  Avg loss: 0.450327
#  Precision: 0.6868
#  Recall: 0.7114
#  F1 Score: 0.6961
#  Matthew's Correlation Coefficient: 0.8443
# Epoch 63
# -------------------------------
# loss: 0.081935  [   32/ 3422]
# loss: 0.082214  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.8%
#  Avg loss: 0.439957
#  Precision: 0.6979
#  Recall: 0.7204
#  F1 Score: 0.7069
#  Matthew's Correlation Coefficient: 0.8511
# Epoch 64
# -------------------------------
# loss: 0.009313  [   32/ 3422]
# loss: 0.060539  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.3%
#  Avg loss: 0.438818
#  Precision: 0.7046
#  Recall: 0.7137
#  F1 Score: 0.7063
#  Matthew's Correlation Coefficient: 0.8577
# Epoch 65
# -------------------------------
# loss: 0.051864  [   32/ 3422]
# loss: 0.024165  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.5%
#  Avg loss: 0.462675
#  Precision: 0.7028
#  Recall: 0.7158
#  F1 Score: 0.7058
#  Matthew's Correlation Coefficient: 0.8475
# Epoch 66
# -------------------------------
# loss: 0.003193  [   32/ 3422]
# loss: 0.043258  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.6%
#  Avg loss: 0.460240
#  Precision: 0.7012
#  Recall: 0.7009
#  F1 Score: 0.6954
#  Matthew's Correlation Coefficient: 0.8482
# Epoch 67
# -------------------------------
# loss: 0.011950  [   32/ 3422]
# loss: 0.036660  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.446038
#  Precision: 0.7010
#  Recall: 0.7068
#  F1 Score: 0.7005
#  Matthew's Correlation Coefficient: 0.8535
# Epoch 68
# -------------------------------
# loss: 0.017599  [   32/ 3422]
# loss: 0.005035  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.438768
#  Precision: 0.6981
#  Recall: 0.7159
#  F1 Score: 0.7036
#  Matthew's Correlation Coefficient: 0.8530
# Epoch 69
# -------------------------------
# loss: 0.007961  [   32/ 3422]
# loss: 0.004486  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.4%
#  Avg loss: 0.436574
#  Precision: 0.7190
#  Recall: 0.7190
#  F1 Score: 0.7169
#  Matthew's Correlation Coefficient: 0.8582
# Epoch 70
# -------------------------------
# loss: 0.013932  [   32/ 3422]
# loss: 0.009829  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.2%
#  Avg loss: 0.443376
#  Precision: 0.7126
#  Recall: 0.7260
#  F1 Score: 0.7167
#  Matthew's Correlation Coefficient: 0.8560
# Epoch 71
# -------------------------------
# loss: 0.048184  [   32/ 3422]
# loss: 0.002744  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.8%
#  Avg loss: 0.449005
#  Precision: 0.7054
#  Recall: 0.7244
#  F1 Score: 0.7131
#  Matthew's Correlation Coefficient: 0.8500
# Epoch 72
# -------------------------------
# loss: 0.059685  [   32/ 3422]
# loss: 0.005429  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.6%
#  Avg loss: 0.454242
#  Precision: 0.6984
#  Recall: 0.7229
#  F1 Score: 0.7083
#  Matthew's Correlation Coefficient: 0.8484
# Epoch 73
# -------------------------------
# loss: 0.004167  [   32/ 3422]
# loss: 0.007683  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.9%
#  Avg loss: 0.446828
#  Precision: 0.6992
#  Recall: 0.7222
#  F1 Score: 0.7084
#  Matthew's Correlation Coefficient: 0.8528
# Epoch 74
# -------------------------------
# loss: 0.001779  [   32/ 3422]
# loss: 0.011353  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.7%
#  Avg loss: 0.450143
#  Precision: 0.6993
#  Recall: 0.7200
#  F1 Score: 0.7077
#  Matthew's Correlation Coefficient: 0.8493
# Epoch 75
# -------------------------------
# loss: 0.024596  [   32/ 3422]
# loss: 0.004674  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.4%
#  Avg loss: 0.442806
#  Precision: 0.7107
#  Recall: 0.7061
#  F1 Score: 0.7060
#  Matthew's Correlation Coefficient: 0.8587
# Epoch 76
# -------------------------------
# loss: 0.085658  [   32/ 3422]
# loss: 0.010545  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.2%
#  Avg loss: 0.449912
#  Precision: 0.7070
#  Recall: 0.7107
#  F1 Score: 0.7066
#  Matthew's Correlation Coefficient: 0.8556
# Epoch 77
# -------------------------------
# loss: 0.003636  [   32/ 3422]
# loss: 0.001531  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.1%
#  Avg loss: 0.446975
#  Precision: 0.6994
#  Recall: 0.7235
#  F1 Score: 0.7095
#  Matthew's Correlation Coefficient: 0.8553
# Epoch 78
# -------------------------------
# loss: 0.005258  [   32/ 3422]
# loss: 0.005503  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.9%
#  Avg loss: 0.447543
#  Precision: 0.7054
#  Recall: 0.7103
#  F1 Score: 0.7058
#  Matthew's Correlation Coefficient: 0.8523
# Epoch 79
# -------------------------------
# loss: 0.009513  [   32/ 3422]
# loss: 0.017071  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.5%
#  Avg loss: 0.449283
#  Precision: 0.7126
#  Recall: 0.7287
#  F1 Score: 0.7184
#  Matthew's Correlation Coefficient: 0.8597
# Epoch 80
# -------------------------------
# loss: 0.005490  [   32/ 3422]
# loss: 0.000485  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.1%
#  Avg loss: 0.450590
#  Precision: 0.7127
#  Recall: 0.7189
#  F1 Score: 0.7127
#  Matthew's Correlation Coefficient: 0.8544
# Epoch 81
# -------------------------------
# loss: 0.009335  [   32/ 3422]
# loss: 0.036763  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.5%
#  Avg loss: 0.447780
#  Precision: 0.7004
#  Recall: 0.7271
#  F1 Score: 0.7121
#  Matthew's Correlation Coefficient: 0.8607
# Epoch 82
# -------------------------------
# loss: 0.008801  [   32/ 3422]
# loss: 0.000695  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.454846
#  Precision: 0.6961
#  Recall: 0.7273
#  F1 Score: 0.7096
#  Matthew's Correlation Coefficient: 0.8540
# Epoch 83
# -------------------------------
# loss: 0.032046  [   32/ 3422]
# loss: 0.002659  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.3%
#  Avg loss: 0.454018
#  Precision: 0.7129
#  Recall: 0.7300
#  F1 Score: 0.7186
#  Matthew's Correlation Coefficient: 0.8576
# Epoch 84
# -------------------------------
# loss: 0.022678  [   32/ 3422]
# loss: 0.007639  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.2%
#  Avg loss: 0.444267
#  Precision: 0.7083
#  Recall: 0.7227
#  F1 Score: 0.7138
#  Matthew's Correlation Coefficient: 0.8557
# Epoch 85
# -------------------------------
# loss: 0.025594  [   32/ 3422]
# loss: 0.006599  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.1%
#  Avg loss: 0.468855
#  Precision: 0.7132
#  Recall: 0.7200
#  F1 Score: 0.7152
#  Matthew's Correlation Coefficient: 0.8545
# Epoch 86
# -------------------------------
# loss: 0.000891  [   32/ 3422]
# loss: 0.004547  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.466061
#  Precision: 0.6956
#  Recall: 0.7275
#  F1 Score: 0.7083
#  Matthew's Correlation Coefficient: 0.8531
# Epoch 87
# -------------------------------
# loss: 0.004269  [   32/ 3422]
# loss: 0.017752  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.1%
#  Avg loss: 0.470498
#  Precision: 0.7071
#  Recall: 0.7229
#  F1 Score: 0.7132
#  Matthew's Correlation Coefficient: 0.8552
# Epoch 88
# -------------------------------
# loss: 0.006501  [   32/ 3422]
# loss: 0.008342  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.6%
#  Avg loss: 0.473359
#  Precision: 0.6918
#  Recall: 0.7233
#  F1 Score: 0.7038
#  Matthew's Correlation Coefficient: 0.8483
# Epoch 89
# -------------------------------
# loss: 0.024629  [   32/ 3422]
# loss: 0.015551  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.8%
#  Avg loss: 0.465616
#  Precision: 0.6891
#  Recall: 0.7263
#  F1 Score: 0.7054
#  Matthew's Correlation Coefficient: 0.8515
# Epoch 90
# -------------------------------
# loss: 0.003403  [   32/ 3422]
# loss: 0.001564  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.467611
#  Precision: 0.6953
#  Recall: 0.7262
#  F1 Score: 0.7085
#  Matthew's Correlation Coefficient: 0.8539
# Epoch 91
# -------------------------------
# loss: 0.000771  [   32/ 3422]
# loss: 0.001163  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.3%
#  Avg loss: 0.462485
#  Precision: 0.7062
#  Recall: 0.7265
#  F1 Score: 0.7132
#  Matthew's Correlation Coefficient: 0.8571
# Epoch 92
# -------------------------------
# loss: 0.006540  [   32/ 3422]
# loss: 0.000184  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.5%
#  Avg loss: 0.477929
#  Precision: 0.6806
#  Recall: 0.7259
#  F1 Score: 0.6994
#  Matthew's Correlation Coefficient: 0.8471
# Epoch 93
# -------------------------------
# loss: 0.016494  [   32/ 3422]
# loss: 0.008312  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.468172
#  Precision: 0.6966
#  Recall: 0.7283
#  F1 Score: 0.7103
#  Matthew's Correlation Coefficient: 0.8541
# Epoch 94
# -------------------------------
# loss: 0.009934  [   32/ 3422]
# loss: 0.001930  [ 3232/ 3422]
# Test Error:
#  Accuracy: 89.8%
#  Avg loss: 0.474541
#  Precision: 0.6972
#  Recall: 0.7225
#  F1 Score: 0.7075
#  Matthew's Correlation Coefficient: 0.8513
# Epoch 95
# -------------------------------
# loss: 0.006151  [   32/ 3422]
# loss: 0.009775  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.1%
#  Avg loss: 0.472584
#  Precision: 0.7008
#  Recall: 0.7250
#  F1 Score: 0.7111
#  Matthew's Correlation Coefficient: 0.8546
# Epoch 96
# -------------------------------
# loss: 0.006926  [   32/ 3422]
# loss: 0.003110  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.4%
#  Avg loss: 0.464450
#  Precision: 0.7109
#  Recall: 0.7254
#  F1 Score: 0.7175
#  Matthew's Correlation Coefficient: 0.8587
# Epoch 97
# -------------------------------
# loss: 0.041790  [   32/ 3422]
# loss: 0.001195  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.4%
#  Avg loss: 0.466053
#  Precision: 0.7070
#  Recall: 0.7203
#  F1 Score: 0.7129
#  Matthew's Correlation Coefficient: 0.8592
# Epoch 98
# -------------------------------
# loss: 0.019148  [   32/ 3422]
# loss: 0.027521  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.3%
#  Avg loss: 0.468131
#  Precision: 0.7049
#  Recall: 0.7270
#  F1 Score: 0.7134
#  Matthew's Correlation Coefficient: 0.8579
# Epoch 99
# -------------------------------
# loss: 0.005013  [   32/ 3422]
# loss: 0.001221  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.0%
#  Avg loss: 0.477463
#  Precision: 0.6975
#  Recall: 0.7253
#  F1 Score: 0.7092
#  Matthew's Correlation Coefficient: 0.8544
# Epoch 100
# -------------------------------
# loss: 0.002900  [   32/ 3422]
# loss: 0.004375  [ 3232/ 3422]
# Test Error:
#  Accuracy: 90.2%
#  Avg loss: 0.472080
#  Precision: 0.7037
#  Recall: 0.7251
#  F1 Score: 0.7129
#  Matthew's Correlation Coefficient: 0.8564
# Done!

# %%
test_loop(valid_loader, nn1, loss_fn)
# Out:
# Test Error:
#  Accuracy: 84.3%
#  Avg loss: 0.456557
#  Precision: 0.4675
#  Recall: 0.4506
#  F1 Score: 0.4502
#  Matthew's Correlation Coefficient: 0.7765
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
torch.save(nn1.state_dict(), '/content/drive/MyDrive/model_NN1_parameters.pth')

# %%
nn2 = NN1()
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(nn1.parameters(), lr=1, weight_decay=1e-5)

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_loader, nn2, loss_fn, optimizer)
    test_loop(test_loader, nn2, loss_fn)
torch.save(nn2.state_dict(), '/content/drive/MyDrive/model_NN2_parameters.pth')
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.911221  [   32/ 3422]
# loss: 1.988787  [ 3232/ 3422]
# Test Error:
#  Accuracy: 17.7%
#  Avg loss: 1.916155
#  Precision: 0.1456
#  Recall: 0.1274
#  F1 Score: 0.0991
#  Matthew's Correlation Coefficient: -0.0053
# Epoch 2
# -------------------------------
# loss: 1.909779  [   32/ 3422]
# loss: 2.024062  [ 3232/ 3422]
# Test Error:
#  Accuracy: 16.9%
#  Avg loss: 1.918852
#  Precision: 0.1481
#  Recall: 0.1198
#  F1 Score: 0.0966
#  Matthew's Correlation Coefficient: -0.0075
# Epoch 3
# -------------------------------
# loss: 1.846298  [   32/ 3422]
# loss: 1.878503  [ 3232/ 3422]
# Test Error:
#  Accuracy: 19.0%
#  Avg loss: 1.912986
#  Precision: 0.1466
#  Recall: 0.1282
#  F1 Score: 0.1013
#  Matthew's Correlation Coefficient: -0.0081
# Epoch 4
# -------------------------------
# loss: 1.864084  [   32/ 3422]
# loss: 1.916119  [ 3232/ 3422]
# Test Error:
#  Accuracy: 17.6%
#  Avg loss: 1.920307
#  Precision: 0.1450
#  Recall: 0.1230
#  F1 Score: 0.0955
#  Matthew's Correlation Coefficient: -0.0102
# Epoch 5
# -------------------------------
# loss: 1.874149  [   32/ 3422]
# loss: 2.035348  [ 3232/ 3422]
# Test Error:
#  Accuracy: 19.0%
#  Avg loss: 1.912342
#  Precision: 0.1457
#  Recall: 0.1171
#  F1 Score: 0.1024
#  Matthew's Correlation Coefficient: -0.0056
# Epoch 6
# -------------------------------
# loss: 1.919492  [   32/ 3422]
# loss: 1.910837  [ 3232/ 3422]
# Test Error:
#  Accuracy: 19.4%
#  Avg loss: 1.909361
#  Precision: 0.1460
#  Recall: 0.1309
#  F1 Score: 0.1017
#  Matthew's Correlation Coefficient: -0.0024
# Epoch 7
# -------------------------------
# loss: 1.906183  [   32/ 3422]
# loss: 1.945677  [ 3232/ 3422]
# Test Error:
#  Accuracy: 16.5%
#  Avg loss: 1.921354
#  Precision: 0.1477
#  Recall: 0.1305
#  F1 Score: 0.0968
#  Matthew's Correlation Coefficient: -0.0048
# Epoch 8
# -------------------------------
# loss: 1.908763  [   32/ 3422]
# loss: 1.758050  [ 3232/ 3422]
# Test Error:
#  Accuracy: 17.8%
#  Avg loss: 1.914809
#  Precision: 0.1404
#  Recall: 0.1294
#  F1 Score: 0.1010
#  Matthew's Correlation Coefficient: -0.0114
# Epoch 9
# -------------------------------
# loss: 1.928882  [   32/ 3422]
# loss: 1.917659  [ 3232/ 3422]
# Test Error:
#  Accuracy: 17.7%
#  Avg loss: 1.921352
#  Precision: 0.1465
#  Recall: 0.1330
#  F1 Score: 0.0977
#  Matthew's Correlation Coefficient: -0.0074
# Epoch 10
# -------------------------------
# loss: 1.854342  [   32/ 3422]
# loss: 1.785676  [ 3232/ 3422]
# Test Error:
#  Accuracy: 18.1%
#  Avg loss: 1.914509
#  Precision: 0.1433
#  Recall: 0.1237
#  F1 Score: 0.1019
#  Matthew's Correlation Coefficient: -0.0068
# Epoch 11
# -------------------------------
# loss: 1.931944  [   32/ 3422]
# loss: 1.963508  [ 3232/ 3422]
# Test Error:
#  Accuracy: 18.3%
#  Avg loss: 1.915499
#  Precision: 0.1474
#  Recall: 0.1209
#  F1 Score: 0.1019
#  Matthew's Correlation Coefficient: -0.0075
# Epoch 12
# -------------------------------
# loss: 1.973683  [   32/ 3422]
# loss: 1.847769  [ 3232/ 3422]
# Test Error:
#  Accuracy: 17.2%
#  Avg loss: 1.919434
#  Precision: 0.1446
#  Recall: 0.1268
#  F1 Score: 0.0966
#  Matthew's Correlation Coefficient: -0.0080
# Epoch 13
# -------------------------------
# loss: 1.814714  [   32/ 3422]
# loss: 1.817841  [ 3232/ 3422]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-8efa7913673d> in <cell line: 6>()
#       7     print(f"Epoch {t+1}\n-------------------------------")
#       8     train_loop(train_loader, nn2, loss_fn, optimizer)
# ----> 9     test_loop(test_loader, nn2, loss_fn)
#      10 torch.save(nn2.state_dict(), '/content/drive/MyDrive/model_NN2_parameters.pth')
#      11 print("Done!")
#
# <ipython-input-39-c90fcb838ebb> in test_loop(dataloader, model, loss_fn)
#      38         for X, y in dataloader:
#      39             X = X.float()
# ---> 40             pred = model(X)
#      41             test_loss += loss_fn(pred, y).item()
#      42             correct += (pred.argmax(1) == y).type(torch.float).sum().item()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-35-470a564b86e5> in forward(self, x)
#      19
#      20     def forward(self, x):
# ---> 21         return self.linear_layers(x)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     215     def forward(self, input):
#     216         for module in self:
# --> 217             input = module(input)
#     218         return input
#     219
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:
